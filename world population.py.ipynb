# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("E:\MSC Data Science\data sets\world_population.csv")

# %%
df.head()
# Out:
#    Rank CCA3 Country/Territory           Capital Continent  2022 Population  \
# 0    36  AFG       Afghanistan             Kabul      Asia         41128771
# 1   138  ALB           Albania            Tirana    Europe          2842321
# 2    34  DZA           Algeria           Algiers    Africa         44903225
# 3   213  ASM    American Samoa         Pago Pago   Oceania            44273
# 4   203  AND           Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
population = df.copy()

# %%
population.describe()
# Out:
#              Rank  2022 Population  2020 Population  2015 Population  \
# count  234.000000     2.340000e+02     2.340000e+02     2.340000e+02
# mean   117.500000     3.407441e+07     3.350107e+07     3.172996e+07
# std     67.694165     1.367664e+08     1.355899e+08     1.304050e+08
# min      1.000000     5.100000e+02     5.200000e+02     5.640000e+02
# 25%     59.250000     4.197385e+05     4.152845e+05     4.046760e+05
# 50%    117.500000     5.559944e+06     5.493074e+06     5.307400e+06
# 75%    175.750000     2.247650e+07     2.144798e+07     1.973085e+07
# max    234.000000     1.425887e+09     1.424930e+09     1.393715e+09
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count     2.340000e+02     2.340000e+02     2.340000e+02     2.340000e+02
# mean      2.984524e+07     2.626947e+07     2.271022e+07     1.898462e+07
# std       1.242185e+08     1.116982e+08     9.783217e+07     8.178519e+07
# ...

# %%
population.columns
# Out:
# Index(['Rank', 'CCA3', 'Country/Territory', 'Capital', 'Continent',
#        '2022 Population', '2020 Population', '2015 Population',
#        '2010 Population', '2000 Population', '1990 Population',
#        '1980 Population', '1970 Population', 'Area (km²)', 'Density (per km²)',
#        'Growth Rate', 'World Population Percentage'],
#       dtype='object')

# %%
population = population.drop(['Rank','CCA3','Capital','Continent','2015 Population','2010 Population','2000 Population','1990 Population','1980 Population','1970 Population','Area (km²)',
                             'Density (per km²)','Growth Rate',], axis =1)

# %%
population.head()
# Out:
#   Country/Territory  2022 Population  2020 Population  \
# 0       Afghanistan         41128771         38972230
# 1           Albania          2842321          2866849
# 2           Algeria         44903225         43451666
# 3    American Samoa            44273            46189
# 4           Andorra            79824            77700
#
#    World Population Percentage
# 0                         0.52
# 1                         0.04
# 2                         0.56
# 3                         0.00
# 4                         0.00

# %%
population.set_index("Country/Territory",drop=True, inplace=True)

# %%
population.head()
# Out:
#                    2022 Population  2020 Population  \
# Country/Territory
# Afghanistan               41128771         38972230
# Albania                    2842321          2866849
# Algeria                   44903225         43451666
# American Samoa               44273            46189
# Andorra                      79824            77700
#
#                    World Population Percentage
# Country/Territory
# Afghanistan                               0.52
# Albania                                   0.04
# Algeria                                   0.56
# American Samoa                            0.00
# Andorra                                   0.00

# %%
population['population change'] = population.loc[:,'2022 Population'] - population.loc[:,'2020 Population']

# %%
population.head()
# Out:
#                    2022 Population  2020 Population  \
# Country/Territory
# Afghanistan               41128771         38972230
# Albania                    2842321          2866849
# Algeria                   44903225         43451666
# American Samoa               44273            46189
# Andorra                      79824            77700
#
#                    World Population Percentage  population change
# Country/Territory
# Afghanistan                               0.52            2156541
# Albania                                   0.04             -24528
# Algeria                                   0.56            1451559
# American Samoa                            0.00              -1916
# Andorra                                   0.00               2124

# %%
population['population change (%)'] = (population.loc[:,'2022 Population'] / population.loc[:,'2020 Population'])*100

# %%
world_population = population.loc[:,'2022 Population']
world_pop_total = world_population.sum()

# %%
world_pop_total
# Out:
# 7973413042

# %%
population.loc["Brazil","2022 Population"]
# Out:
# 215313498

# %%
(population.loc["Afghanistan","2022 Population"]/world_pop_total)*100
# Out:
# 0.515823911082418

# %%
population.at["Albania","2022 Population"] = 0

# %%
population.head()
# Out:
#                    2022 Population  2020 Population  \
# Country/Territory
# Afghanistan               41128771         38972230
# Albania                          0          2866849
# Algeria                   44903225         43451666
# American Samoa               44273            46189
# Andorra                      79824            77700
#
#                    World Population Percentage  population change  \
# Country/Territory
# Afghanistan                               0.52            2156541
# Albania                                   0.04             -24528
# Algeria                                   0.56            1451559
# American Samoa                            0.00              -1916
# Andorra                                   0.00               2124
#
#                    population change (%)
# Country/Territory
# Afghanistan                   105.533532
# Albania                        99.144427
# Algeria                       103.340629
# ...

# %%
population.loc["China"]
# Out:
# 2022 Population                1.425887e+09
# 2020 Population                1.424930e+09
# World Population Percentage    1.788000e+01
# population change              9.575560e+05
# population change (%)          1.000672e+02
# Name: China, dtype: float64

# %%
population.at["China","2022 Population"] = population.at["China","2022 Population"]*2

# %%
population.loc["China"]
# Out:
# 2022 Population                2.851775e+09
# 2020 Population                1.424930e+09
# World Population Percentage    1.788000e+01
# population change              9.575560e+05
# population change (%)          1.000672e+02
# Name: China, dtype: float64

# %%
population.iloc[2]
# Out:
# 2022 Population                4.490322e+07
# 2020 Population                4.345167e+07
# World Population Percentage    5.600000e-01
# population change              1.451559e+06
# population change (%)          1.033406e+02
# Name: Algeria, dtype: float64

# %%
population.loc["Algeria"]
# Out:
# 2022 Population                4.490322e+07
# 2020 Population                4.345167e+07
# World Population Percentage    5.600000e-01
# population change              1.451559e+06
# population change (%)          1.033406e+02
# Name: Algeria, dtype: float64

# %%
population.at["Albania","World Population Percentage"]
# Out:
# 0.04

# %%
population.iat[1,2]
# Out:
# 0.04

# %%
geography = df.copy()

# %%
geography.head()
# Out:
#    Rank CCA3 Country/Territory           Capital Continent  2022 Population  \
# 0    36  AFG       Afghanistan             Kabul      Asia         41128771
# 1   138  ALB           Albania            Tirana    Europe          2842321
# 2    34  DZA           Algeria           Algiers    Africa         44903225
# 3   213  ASM    American Samoa         Pago Pago   Oceania            44273
# 4   203  AND           Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
asia = geography[ geography['Continent'].isin(['Asia'])]
asia.head()
# Out:
#     Rank CCA3 Country/Territory  Capital Continent  2022 Population  \
# 0     36  AFG       Afghanistan    Kabul      Asia         41128771
# 9    140  ARM           Armenia  Yerevan      Asia          2780469
# 13    91  AZE        Azerbaijan     Baku      Asia         10358074
# 15   154  BHR           Bahrain   Manama      Asia          1472233
# 16     8  BGD        Bangladesh    Dhaka      Asia        171186372
#
#     2020 Population  2015 Population  2010 Population  2000 Population  \
# 0          38972230         33753499         28189672         19542982
# 9           2805608          2878595          2946293          3168523
# 13         10284951          9863480          9237202          8190337
# 15          1477469          1362142          1213645           711442
# 16        167420951        157830000        148391139        129193327
#
#     1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
geography["Continent"].isin(['Asia'])
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 229    False
# 230    False
# 231     True
# 232    False
# 233    False
# Name: Continent, Length: 234, dtype: bool
